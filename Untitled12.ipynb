# %% [markdown]
# <a href="https://colab.research.google.com/github/santiagovillamizarjaimes-collab/Tareas-Python-Erick/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Ejercicio 1**

# %%
def suma(z1, z2):
  resultado = z1 + z2
  return resultado

def multiplicacion(z1, z2):
  resultado = z1 * z2
  return resultado

def raiz_n(z, n):
  resultado = z ** (1/n)
  return resultado

def pedir_complejo():
  real = float(input("Ingrese la parte real: "))
  imag = float(input("Ingrese la parte imaginaria: "))
  z = complex(real, imag)
  return z

opcion = 0

while True:
  try:
    print("------MENU DE OPCIONES------")
    print("1. Sumar numeros complejos")
    print("2. Multiplicar numeros complejos")
    print("3. Raiz n-esima de un numero complejo")
    print("4. Salir")

    opcion = int(input("Elige una opción: "))


    if opcion == 1:
      print("Ingrese el primer complejo")
      z1 = pedir_complejo()
      print("Ingrese el segundo complejo")
      z2 = pedir_complejo()
      r = suma(z1, z2)
      print("La suma es:", r)

    elif opcion == 2:
      print("Ingrese el primer complejo")
      z1 = pedir_complejo()
      print("Ingrese el segundo complejo")
      z2 = pedir_complejo()
      r = multiplicacion(z1, z2)
      print("La multiplicacion es:", r)

    elif opcion == 3:
      print("Ingrese el numero complejo")
      z = pedir_complejo()
      print("Ingrese el valor de n:")
      n = int(input("Ingrese el indice radical"))
      r = raiz_n(z, n)
      print("La raiz es:", r)

    elif opcion == 4:
      print("Fin del programa")
      break

  except ValueError:
    print("Opcion incorrecta")
# Out:
# ------MENU DE OPCIONES------
# 1. Sumar numeros complejos
# 2. Multiplicar numeros complejos
# 3. Raiz n-esima de un numero complejo
# 4. Salir
# Elige una opción: a
# Opcion incorrecta
# ------MENU DE OPCIONES------
# 1. Sumar numeros complejos
# 2. Multiplicar numeros complejos
# 3. Raiz n-esima de un numero complejo
# 4. Salir
# Elige una opción: 4
# Fin del programa
